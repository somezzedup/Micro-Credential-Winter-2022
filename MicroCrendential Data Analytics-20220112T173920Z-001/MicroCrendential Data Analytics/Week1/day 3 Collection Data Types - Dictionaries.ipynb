# %% [markdown]
# #Collection Data Types
#
# #Dictionaries

# %%
patient_1 = {'first_name': 'john', 'last_name':'kimble'}
print(patient_1['first_name'])
print(patient_1['last_name'])
# Out:
# john
# kimble

# %%
#Accessing dictionaries

patient_name = patient_1['first_name']

print("hello there, " + patient_name)
# Out:
# hello there. john

# %%
patient_={}

# %%
patient_2['first_name']='john'

# %%
patient_2['last_name']='wick'

# %%
patient_2
# Out:
# {'First Name': 'john',
#  'Fist Name': 'john',
#  'Last Name': 'wick',
#  'first_name': 'john',
#  'last_name': 'wick'}

# %%
patient_2['Fruits']='Apple'

# %%
patient_2['Object']='Floor'

# %%
patient_2['Laptop']='Dell'

# %%
del patient_2['Object']

# %%
patient_2
# Out:
# {'First Name': 'john',
#  'Fist Name': 'john',
#  'Fruits': 'Apple',
#  'Laptop': 'Dell',
#  'Last Name': 'wick',
#  'first_name': 'john',
#  'last_name': 'wick'}

# %%
del patient_2['First Name']

# %%
patient_2
# Out:
# {'Fist Name': 'john',
#  'Fruits': 'Apple',
#  'Laptop': 'Dell',
#  'Last Name': 'wick',
#  'first_name': 'john',
#  'last_name': 'wick'}

# %%
del patient_2['Fist Name']

# %%
patient_2
# Out:
# {'Fruits': 'Apple',
#  'Laptop': 'Dell',
#  'Last Name': 'wick',
#  'first_name': 'john',
#  'last_name': 'wick'}

# %%
patient_2['Object']=['fruits','13.3','strings']

# %%
patient_2['Object'][0]
# Out:
# 'fruits'

# %%
#since first argument is a string we can find the index of the character
patient_2['Object'][0][2]
# Out:
# 'u'

# %%
patient_2['Object'][0].upper()
# Out:
# 'FRUITS'

# %%
patient_3={'first_name':'Tony', 
           'last_name': 'Stark',
           'date_of_birth':'03/15/1980',
           'mrn':'0012347'}
print(patient_3)
# Out:
# {'first_name': 'Tony', 'last_name': 'Stark', 'date_of_birth': '03/15/1980', 'mrn': '0012347'}

# %%
print("Patient 3 DOB is " + patient_3['date_of_birth'])
# Out:
# Patient 3 DOB is 03/15/1980

# %%
#string formatting

print(f'The first name of the patient is {patient_3["first_name"]}')
print(f'The last name of the patient is {patient_3["last_name"]}')
print(f'The DOB of the patient is {patient_3["date_of_birth"]}')
# Out:
# The first name of the patient is Tony
# The last name of the patient is Stark
# The DOB of the patient is 03/15/1980

# %% [markdown]
# #Nesting with Dictionaries

# %%
#Dictionary nested inside a dictionary nested inside a dictionary
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
# Keep calling the keys
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %% [markdown]
# #Dictionary methods

# %%
# Create a typical dictionary
d = {'key1':1,'key2':2,'key3':3}

# %%
# Method to return a list of all keys 
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
# Method to grab all values
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
# Method to return tuples of all items  
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])
